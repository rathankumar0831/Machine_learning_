# %% [markdown]
# ## simple Linear Regression

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('Salary_dataset.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  YearsExperience   Salary
# 0           0              1.2  39344.0
# 1           1              1.4  46206.0
# 2           2              1.6  37732.0
# 3           3              2.1  43526.0
# 4           4              2.3  39892.0

# %%
# visualizing the distribution by using the scatter plot 
plt.scatter(df['YearsExperience'], df['Salary'])

# %%
## independent and dependent features
X = df[['YearsExperience']]
y = df['Salary']

# %%
X, y
# Out:
# (    YearsExperience
#  0               1.2
#  1               1.4
#  2               1.6
#  3               2.1
#  4               2.3
#  5               3.0
#  6               3.1
#  7               3.3
#  8               3.3
#  9               3.8
#  10              4.0
#  11              4.1
#  12              4.1
#  13              4.2
#  14              4.6
#  15              5.0
#  16              5.2
#  17              5.4
#  18              6.0
#  19              6.1
#  20              6.9
#  21              7.2
#  22              8.0
#  23              8.3
#  24              8.8
#  25              9.1
#  26              9.6
#  27              9.7
#  28             10.4
#  29             10.6,
#  0      39344.0
#  1      46206.0
#  2      37732.0
#  3      43526.0
#  4      39892.0
#  5      56643.0
#  6      60151.0
#  7      54446.0
#  8      64446.0
#  9      57190.0
#  10     63219.0
#  11     55795.0
#  12     56958.0
#  13     57082.0
#  14     61112.0
#  15     67939.0
#  16     66030.0
#  17     83089.0
#  18     81364.0
#  19     93941.0
#  20     91739.0
#  21     98274.0
#  22    101303.0
#  23    113813.0
#  24    109432.0
#  25    105583.0
#  26    116970.0
#  27    112636.0
#  28    122392.0
#  29    121873.0
#  Name: Salary, dtype: float64)

# %%
## Train Test split
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.33, random_state=42)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((20, 1), (10, 1), (20,), (10,))

# %%
# standardization
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()

# %%
regressor
# Out:
# LinearRegression()

# %%
regressor.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(X_test)

# %%
y_pred
# Out:
# array([115815.30756236,  71512.92534771, 102618.85328566,  75283.34085534,
#         55488.65944028,  60201.67882482, 122413.53470072, 107331.8726702 ,
#         63029.49045554,  35693.97802523])

# %%
plt.scatter(y_test, y_pred)

# %%
plt.scatter(X_test, y_test)
plt.plot(X_train, regressor.predict(X_train), 'r+')

# %%
plt.scatter(X_test, y_test)
plt.plot(X_train, regressor.predict(X_train), 'r')

# %%
residual = y_test-y_pred

# %%
residual
# Out:
# 27    -3179.307562
# 15    -3573.925348
# 23    11194.146714
# 17     7805.659145
# 8      8957.340560
# 9     -3011.678825
# 28      -21.534701
# 24     2100.127330
# 12    -6071.490456
# 0      3650.021975
# Name: Salary, dtype: float64

# %%
import seaborn as sns
sns.displot(residual, kind = 'kde')

# %%
## scatter plot with prediction and residuals 
plt.scatter(y_pred, residual)

# %% [markdown]
# #### Above distributiobn is uniform distribution here the performance is good
